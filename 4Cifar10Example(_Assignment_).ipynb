# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAI-Lady/30-seconds-of-code/blob/master/4Cifar10Example(_Assignment_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-c0b33b14-8db5-a6f8-420c-8ef6012eb33d)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models

from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, SGD
from keras.utils import np_utils
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers
from keras.callbacks import LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('ggplot')

# %%
#Define learning rate
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 50:
        lrate = 0.0005
    elif epoch > 75:
        lrate = 0.0003        
    return lrate

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Parse numbers as floats
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
# Normalize pixel values to be between 0 and 1
x_train /= 255.0
x_test /= 255.0

# %%
num_classes = 10
#convert array of labeled data to one-hot vector.
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %%
#Create the model
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(256, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# #### Data preprocessing

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 256)       7168
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 256)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       295040
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 32)          36896
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 32)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 32)          9248
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 32)          0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                1290
# =================================================================
# Total params: 1,386,826
# Trainable params: 1,384,650
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(x_train)

# %%
#training
batch_size = 64
epoch_size = 100

#Compile model
keras.optimizers.RMSprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=epoch_size,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 781/781 [==============================] - 45s 55ms/step - loss: 1.7609 - accuracy: 0.4148 - val_loss: 1.2156 - val_accuracy: 0.6074
# Epoch 2/100
# 781/781 [==============================] - 40s 52ms/step - loss: 1.2591 - accuracy: 0.5962 - val_loss: 1.3199 - val_accuracy: 0.6177
# Epoch 3/100
# 781/781 [==============================] - 41s 52ms/step - loss: 1.0690 - accuracy: 0.6773 - val_loss: 1.1241 - val_accuracy: 0.6843
# Epoch 4/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.9849 - accuracy: 0.7198 - val_loss: 1.0313 - val_accuracy: 0.7112
# Epoch 5/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.9399 - accuracy: 0.7426 - val_loss: 0.8644 - val_accuracy: 0.7690
# Epoch 6/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8815 - accuracy: 0.7662 - val_loss: 0.9891 - val_accuracy: 0.7502
# Epoch 7/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8644 - accuracy: 0.7762 - val_loss: 1.2819 - val_accuracy: 0.6610
# Epoch 8/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8540 - accuracy: 0.7850 - val_loss: 0.8507 - val_accuracy: 0.7892
# Epoch 9/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8278 - accuracy: 0.7937 - val_loss: 0.8366 - val_accuracy: 0.7926
# Epoch 10/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8186 - accuracy: 0.8002 - val_loss: 0.8681 - val_accuracy: 0.7830
# Epoch 11/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8100 - accuracy: 0.8050 - val_loss: 0.9103 - val_accuracy: 0.7856
# Epoch 12/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.8117 - accuracy: 0.8073 - val_loss: 0.7932 - val_accuracy: 0.8163
# Epoch 13/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7911 - accuracy: 0.8172 - val_loss: 0.7461 - val_accuracy: 0.8349
# Epoch 14/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7830 - accuracy: 0.8221 - val_loss: 0.9008 - val_accuracy: 0.7856
# Epoch 15/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7703 - accuracy: 0.8245 - val_loss: 0.7221 - val_accuracy: 0.8376
# Epoch 16/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7602 - accuracy: 0.8273 - val_loss: 0.8165 - val_accuracy: 0.8101
# Epoch 17/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7631 - accuracy: 0.8269 - val_loss: 0.8645 - val_accuracy: 0.8013
# Epoch 18/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7519 - accuracy: 0.8325 - val_loss: 0.7858 - val_accuracy: 0.8275
# Epoch 19/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7492 - accuracy: 0.8366 - val_loss: 0.8273 - val_accuracy: 0.8162
# Epoch 20/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7416 - accuracy: 0.8384 - val_loss: 0.7787 - val_accuracy: 0.8334
# Epoch 21/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7528 - accuracy: 0.8346 - val_loss: 0.8069 - val_accuracy: 0.8278
# Epoch 22/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7340 - accuracy: 0.8443 - val_loss: 0.7968 - val_accuracy: 0.8229
# Epoch 23/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7319 - accuracy: 0.8401 - val_loss: 0.7903 - val_accuracy: 0.8295
# Epoch 24/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7269 - accuracy: 0.8454 - val_loss: 0.7652 - val_accuracy: 0.8344
# Epoch 25/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7170 - accuracy: 0.8466 - val_loss: 0.6998 - val_accuracy: 0.8486
# Epoch 26/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7187 - accuracy: 0.8446 - val_loss: 0.8970 - val_accuracy: 0.8027
# Epoch 27/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7205 - accuracy: 0.8483 - val_loss: 0.7557 - val_accuracy: 0.8374
# Epoch 28/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7096 - accuracy: 0.8497 - val_loss: 0.8131 - val_accuracy: 0.8235
# Epoch 29/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7077 - accuracy: 0.8488 - val_loss: 0.8050 - val_accuracy: 0.8229
# Epoch 30/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7083 - accuracy: 0.8505 - val_loss: 0.7201 - val_accuracy: 0.8506
# Epoch 31/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7057 - accuracy: 0.8520 - val_loss: 0.7181 - val_accuracy: 0.8506
# Epoch 32/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6980 - accuracy: 0.8546 - val_loss: 0.7916 - val_accuracy: 0.8285
# Epoch 33/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7027 - accuracy: 0.8538 - val_loss: 0.8408 - val_accuracy: 0.8207
# Epoch 34/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6997 - accuracy: 0.8545 - val_loss: 0.8407 - val_accuracy: 0.8225
# Epoch 35/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.7038 - accuracy: 0.8550 - val_loss: 0.8846 - val_accuracy: 0.8055
# Epoch 36/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6845 - accuracy: 0.8580 - val_loss: 0.7535 - val_accuracy: 0.8422
# Epoch 37/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6870 - accuracy: 0.8577 - val_loss: 0.7441 - val_accuracy: 0.8445
# Epoch 38/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6858 - accuracy: 0.8588 - val_loss: 0.7241 - val_accuracy: 0.8472
# Epoch 39/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6872 - accuracy: 0.8594 - val_loss: 0.7802 - val_accuracy: 0.8298
# Epoch 40/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6810 - accuracy: 0.8593 - val_loss: 0.8685 - val_accuracy: 0.8064
# Epoch 41/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6802 - accuracy: 0.8599 - val_loss: 0.8105 - val_accuracy: 0.8308
# Epoch 42/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.6760 - accuracy: 0.8620 - val_loss: 0.7300 - val_accuracy: 0.8481
# Epoch 43/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0
100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4884 - accuracy: 0.9007 - val_loss: 0.5541 - val_accuracy: 0.8861
# Epoch 69/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4858 - accuracy: 0.9008 - val_loss: 0.6114 - val_accuracy: 0.8665
# Epoch 70/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4851 - accuracy: 0.8997 - val_loss: 0.5361 - val_accuracy: 0.8879
# Epoch 71/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4873 - accuracy: 0.9012 - val_loss: 0.5737 - val_accuracy: 0.8795
# Epoch 72/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4787 - accuracy: 0.9016 - val_loss: 0.5730 - val_accuracy: 0.8798
# Epoch 73/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4746 - accuracy: 0.9054 - val_loss: 0.5503 - val_accuracy: 0.8841
# Epoch 74/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4781 - accuracy: 0.9014 - val_loss: 0.6065 - val_accuracy: 0.8745
# Epoch 75/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4686 - accuracy: 0.9053 - val_loss: 0.5803 - val_accuracy: 0.8772
# Epoch 76/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4789 - accuracy: 0.9030 - val_loss: 0.5648 - val_accuracy: 0.8804
# Epoch 77/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4689 - accuracy: 0.9047 - val_loss: 0.5437 - val_accuracy: 0.8878
# Epoch 78/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4690 - accuracy: 0.9041 - val_loss: 0.4955 - val_accuracy: 0.8976
# Epoch 79/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4751 - accuracy: 0.9013 - val_loss: 0.5375 - val_accuracy: 0.8850
# Epoch 80/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4727 - accuracy: 0.9038 - val_loss: 0.5933 - val_accuracy: 0.8712
# Epoch 81/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4720 - accuracy: 0.9044 - val_loss: 0.5419 - val_accuracy: 0.8861
# Epoch 82/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4650 - accuracy: 0.9066 - val_loss: 0.5654 - val_accuracy: 0.8833
# Epoch 83/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4663 - accuracy: 0.9056 - val_loss: 0.5513 - val_accuracy: 0.8845
# Epoch 84/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4709 - accuracy: 0.9030 - val_loss: 0.5006 - val_accuracy: 0.8997
# Epoch 85/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4674 - accuracy: 0.9048 - val_loss: 0.6014 - val_accuracy: 0.8659
# Epoch 86/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4612 - accuracy: 0.9079 - val_loss: 0.5187 - val_accuracy: 0.8919
# Epoch 87/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4624 - accuracy: 0.9053 - val_loss: 0.5256 - val_accuracy: 0.8940
# Epoch 88/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4620 - accuracy: 0.9054 - val_loss: 0.5065 - val_accuracy: 0.8937
# Epoch 89/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4660 - accuracy: 0.9043 - val_loss: 0.5173 - val_accuracy: 0.8942
# Epoch 90/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4637 - accuracy: 0.9074 - val_loss: 0.6617 - val_accuracy: 0.8537
# Epoch 91/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4672 - accuracy: 0.9059 - val_loss: 0.5346 - val_accuracy: 0.8869
# Epoch 92/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4664 - accuracy: 0.9054 - val_loss: 0.5198 - val_accuracy: 0.8931
# Epoch 93/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4669 - accuracy: 0.9038 - val_loss: 0.5698 - val_accuracy: 0.8778
# Epoch 94/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4643 - accuracy: 0.9076 - val_loss: 0.5140 - val_accuracy: 0.8957
# Epoch 95/100
# 781/781 [==============================] - 41s 53ms/step - loss: 0.4610 - accuracy: 0.9050 - val_loss: 0.6859 - val_accuracy: 0.8449
# Epoch 96/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4615 - accuracy: 0.9072 - val_loss: 0.5513 - val_accuracy: 0.8853
# Epoch 97/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4705 - accuracy: 0.9045 - val_loss: 0.5259 - val_accuracy: 0.8874
# Epoch 98/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4654 - accuracy: 0.9071 - val_loss: 0.5302 - val_accuracy: 0.8867
# Epoch 99/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4621 - accuracy: 0.9059 - val_loss: 0.5625 - val_accuracy: 0.8811
# Epoch 100/100
# 781/781 [==============================] - 41s 52ms/step - loss: 0.4634 - accuracy: 0.9062 - val_loss: 0.4980 - val_accuracy: 0.8987

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 256)       7168
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 256)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       295040
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 32)          36896
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 32)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 32)          9248
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 32)          0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 32)          128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                1290
# =================================================================
# Total params: 1,386,826
# Trainable params: 1,384,650
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
#testing
scores = model.evaluate(x_test, y_test, verbose=1)
print('\nTest accuracy: %.3f Test loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4980 - accuracy: 0.8987
#
# Test accuracy: 89.870 Test loss: 0.498

# %%
f, (plt1, plt2) = plt.subplots(1, 2,figsize=(15,5))

plt1.plot(history.history['accuracy'])
plt1.plot(history.history['val_accuracy'])
plt1.set_title('Accuracy (Higher Better)')
plt1.set(xlabel='Epoch', ylabel='Accuracy')
plt1.legend(['train', 'validation'], loc='lower right')
plt1.xaxis.set_major_locator(MaxNLocator(integer=True))

plt2.plot(history.history['loss'])
plt2.plot(history.history['val_loss'])
plt2.set_title('Loss (Lower Better)')
plt2.set(xlabel='Epoch', ylabel='Loss')
plt2.legend(['train', 'validation'], loc='upper right')
plt2.xaxis.set_major_locator(MaxNLocator(integer=True))

# %%
output = model.predict_classes(x_test)
print (output)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [3 8 8 ... 5 1 7]

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = y_train.reshape(y_train.shape[0])
y_test = y_test.reshape(y_test.shape[0])
ind = np.where(np.equal(output, y_test)==0)

# %%
err_x = x_test[ind[0]]
err_y = output[ind[0]]
print (err_x.shape)
# Out:
# (1013, 32, 32, 3)

# %%
examples_per_class = 6
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

for cls, cls_name in enumerate(classes):
  idxs = np.where(cls == err_y)
  idxs = np.random.choice(idxs[0], examples_per_class, replace=False)
  for i, idx in enumerate(idxs):
    plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
    plt.imshow(err_x[idx].astype('uint8'), cmap = 'gray')
    plt.axis('off')
    if i == 0:
      plt.title(cls_name)
