# %% [markdown]
# <a href="https://colab.research.google.com/github/TheAI-Lady/30-seconds-of-code/blob/master/Dawnet_Cifar10_Assignment_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi -L
# Out:
# GPU 0: Tesla K80 (UUID: GPU-31fff14a-da01-2c10-0352-b67d4d45318f)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models

from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, SGD
from keras.utils import np_utils
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers
from keras.callbacks import LearningRateScheduler
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('ggplot')

# %%
#Define learning rate
'''
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 50:
        lrate = 0.0005
    elif epoch > 75:
        lrate = 0.0003        
    return lrate
'''
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 50:
        lrate = 0.0005
    if epoch > 75:
        lrate = 0.0003
    elif epoch > 100:
        lrate = 0.0001        
    return lrate

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

img_rows, img_cols = 32, 32
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
 
print ("x_train: ", x_train.shape)
print ("y_train: ", y_train.shape)
print ("x_test: ", x_test.shape)
print ("x_test: ", y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# x_train:  (50000, 32, 32, 3)
# y_train:  (50000, 1)
# x_test:  (10000, 32, 32, 3)
# x_test:  (10000, 1)

# %%
# Parse numbers as floats
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
# Normalize pixel values to be between 0 and 1
x_train /= 255.0
x_test /= 255.0

# %%
num_classes = 10
#convert array of labeled data to one-hot vector.
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %%
#Create the model
weight_decay = 1e-4

#Layer1: BatchNormalization
model = Sequential()
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

#Layer2: BatchNormalization+Dropout(0.2)
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

#Layer3: BatchNormalization
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

#Layer4: BatchNormalization+MaxPooling+Dropout(0.3)
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

#Layer5: BatchNormalization
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

#Layer6: BatchNormalization+MaxPooling+Dropout(0.4)
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

#Layer7: BatchNormalization
model.add(Conv2D(256, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

#Layer8: BatchNormalization+MaxPooling+Dropout(0.5)
model.add(Conv2D(256, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# #### Data preprocessing

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                10250
# =================================================================
# Total params: 1,455,434
# Trainable params: 1,453,130
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.4,
    fill_mode="nearest"
    )
datagen.fit(x_train)

# %%
#training
batch_size = 64 # number of samples to be used for each gradient update
epoch_size = 125 # number of iterations over the entire x_train data

#Compile model
opt= keras.optimizers.RMSprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy',optimizer=opt, metrics=['accuracy'])
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=epoch_size,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/125
# 781/781 [==============================] - 58s 71ms/step - loss: 1.1985 - accuracy: 0.6859 - val_loss: 1.2017 - val_accuracy: 0.7060
# Epoch 2/125
# 781/781 [==============================] - 53s 68ms/step - loss: 1.1556 - accuracy: 0.7026 - val_loss: 1.0109 - val_accuracy: 0.7501
# Epoch 3/125
# 781/781 [==============================] - 53s 68ms/step - loss: 1.1166 - accuracy: 0.7150 - val_loss: 1.1074 - val_accuracy: 0.7325
# Epoch 4/125
# 781/781 [==============================] - 53s 67ms/step - loss: 1.1077 - accuracy: 0.7207 - val_loss: 1.1514 - val_accuracy: 0.7165
# Epoch 5/125
# 781/781 [==============================] - 52s 67ms/step - loss: 1.0741 - accuracy: 0.7328 - val_loss: 1.0615 - val_accuracy: 0.7675
# Epoch 6/125
# 781/781 [==============================] - 53s 67ms/step - loss: 1.0674 - accuracy: 0.7384 - val_loss: 0.9402 - val_accuracy: 0.7838
# Epoch 7/125
# 781/781 [==============================] - 53s 68ms/step - loss: 1.0409 - accuracy: 0.7462 - val_loss: 0.9395 - val_accuracy: 0.7844
# Epoch 8/125
# 781/781 [==============================] - 52s 67ms/step - loss: 1.0252 - accuracy: 0.7495 - val_loss: 1.0472 - val_accuracy: 0.7459
# Epoch 9/125
# 781/781 [==============================] - 51s 65ms/step - loss: 1.0045 - accuracy: 0.7603 - val_loss: 1.0571 - val_accuracy: 0.7568
# Epoch 10/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.9903 - accuracy: 0.7659 - val_loss: 0.8501 - val_accuracy: 0.8129
# Epoch 11/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.9992 - accuracy: 0.7606 - val_loss: 1.0220 - val_accuracy: 0.7526
# Epoch 12/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.9834 - accuracy: 0.7666 - val_loss: 0.7927 - val_accuracy: 0.8343
# Epoch 13/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.9617 - accuracy: 0.7726 - val_loss: 0.9895 - val_accuracy: 0.7822
# Epoch 14/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.9602 - accuracy: 0.7750 - val_loss: 0.9325 - val_accuracy: 0.7837
# Epoch 15/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.9393 - accuracy: 0.7792 - val_loss: 0.9485 - val_accuracy: 0.7822
# Epoch 16/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.9377 - accuracy: 0.7782 - val_loss: 0.9567 - val_accuracy: 0.7854
# Epoch 17/125
# 781/781 [==============================] - 51s 65ms/step - loss: 0.9167 - accuracy: 0.7890 - val_loss: 0.8411 - val_accuracy: 0.8166
# Epoch 18/125
# 781/781 [==============================] - 51s 65ms/step - loss: 0.9148 - accuracy: 0.7891 - val_loss: 0.9587 - val_accuracy: 0.7868
# Epoch 19/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8998 - accuracy: 0.7883 - val_loss: 0.8648 - val_accuracy: 0.8121
# Epoch 20/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.8989 - accuracy: 0.7920 - val_loss: 0.8356 - val_accuracy: 0.8214
# Epoch 21/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8979 - accuracy: 0.7913 - val_loss: 0.7929 - val_accuracy: 0.8312
# Epoch 22/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.8673 - accuracy: 0.8052 - val_loss: 0.8293 - val_accuracy: 0.8211
# Epoch 23/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8767 - accuracy: 0.8014 - val_loss: 0.8099 - val_accuracy: 0.8231
# Epoch 24/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8667 - accuracy: 0.8003 - val_loss: 0.8267 - val_accuracy: 0.8249
# Epoch 25/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8669 - accuracy: 0.8038 - val_loss: 0.8583 - val_accuracy: 0.8166
# Epoch 26/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.8543 - accuracy: 0.8071 - val_loss: 0.7378 - val_accuracy: 0.8453
# Epoch 27/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8618 - accuracy: 0.8051 - val_loss: 0.7306 - val_accuracy: 0.8475
# Epoch 28/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.8363 - accuracy: 0.8120 - val_loss: 0.8364 - val_accuracy: 0.8179
# Epoch 29/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8483 - accuracy: 0.8056 - val_loss: 0.7369 - val_accuracy: 0.8490
# Epoch 30/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8433 - accuracy: 0.8089 - val_loss: 0.8607 - val_accuracy: 0.8133
# Epoch 31/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8389 - accuracy: 0.8060 - val_loss: 0.8246 - val_accuracy: 0.8236
# Epoch 32/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8387 - accuracy: 0.8092 - val_loss: 0.7575 - val_accuracy: 0.8425
# Epoch 33/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.8290 - accuracy: 0.8134 - val_loss: 0.7441 - val_accuracy: 0.8460
# Epoch 34/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.8270 - accuracy: 0.8140 - val_loss: 0.7818 - val_accuracy: 0.8324
# Epoch 35/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.8167 - accuracy: 0.8167 - val_loss: 0.7682 - val_accuracy: 0.8381
# Epoch 36/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.8227 - accuracy: 0.8158 - val_loss: 0.7498 - val_accuracy: 0.8451
# Epoch 37/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8221 - accuracy: 0.8164 - val_loss: 0.7296 - val_accuracy: 0.8530
# Epoch 38/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8095 - accuracy: 0.8174 - val_loss: 0.8267 - val_accuracy: 0.8212
# Epoch 39/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8037 - accuracy: 0.8206 - val_loss: 0.7888 - val_accuracy: 0.8322
# Epoch 40/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.8085 - accuracy: 0.8193 - val_loss: 0.7629 - val_accuracy: 0.8413
# Epoch 41/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.7887 - accuracy: 0.8283 - val_loss: 0.8006 - val_accuracy: 0.8260
# Epoch 42/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.7984 - accuracy: 0.8217 - val_loss: 0.7811 - val_accuracy: 0.8393
# Epoch 43/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.8059 - accuracy: 0.8165 - val_loss: 0.8160 - val_accuracy: 0.8245
# Epoch 44/125
# 781/781 [==============================] - 50s 64ms/step - loss: 0.7905 - accuracy: 0.8253 - val_loss: 0.7248 - val_accuracy: 0.8481
# Epoch 45/125
# 781/781 [==============================] - 49s 63ms/step - loss: 0.7982 - accuracy: 0.8195 - val_loss: 0.8244 - val_accuracy: 0.8213
# Epoch 46/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.7888 - accuracy: 0.8239 - val_loss: 0.8078 - val_accuracy: 0.8252
# Epoch 47/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.8018 - accuracy: 0.8217 - val_loss: 0.8254 - val_accuracy: 0.8226
# Epoch 48/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.7820 - accuracy: 0.8281 - val_loss: 0.7094 - val_accuracy: 0.8560
# Epoch 49/125
# 781/781 [==============================] - 51s 65ms/step - loss: 0.7801 - accuracy: 0.8278 - val_loss: 0.8359 - val_accuracy: 0.8209
# Epoch 50/125
# 781/781 [==============================] - 51s 65ms/step - loss: 0.7876 - accuracy: 0.8226 - val_loss: 0.6773 - val_accuracy: 0.8659
# Epoch 51/125
# 781/781 [==============================] - 51s 65ms/step - loss: 0.7827 - accuracy: 0.8250 - val_loss: 0.7164 - val_accuracy: 0.8504
# Epoch 52/125
# 781/781 [==============================] - 51s 65ms/step - loss: 0.7377 - accuracy: 0.8384 - val_loss: 0.6625 - val_accuracy: 0.8737
# Epoch 53/125
# 781/781 [==============================] - 51s 66ms/step - loss: 0.6895 - accuracy: 0.8548 - val_loss: 0.6315 - val_accuracy: 0.8774
# Epoch 54/125
# 781/781 [==============================] - 52s 66ms/step - loss: 0.6757 - accuracy: 0.8538 - val_loss: 0.5969 - val_accuracy: 0.8825
# Epoch 55/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.6632 - accuracy: 0.8550 - val_loss: 0.5506 - val_accuracy: 0.8967
# Epoch 56/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6440 - accuracy: 0.8581 - val_loss: 0.6065 - val_accuracy: 0.8789
# Epoch 57/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6415 - accuracy: 0.8616 - val_loss: 0.5756 - val_accuracy: 0.8812
# Epoch 58/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6405 - accuracy: 0.8566 - val_loss: 0.5306 - val_accuracy: 0.8972
# Epoch 59/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6299 - accuracy: 0.8609 - val_loss: 0.6312 - val_accuracy: 0.8664
# Epoch 60/125
# 781/781 [==============================] - 54s 70ms/step - loss: 0.6271 - accuracy: 0.8592 - val_loss: 0.5481 - val_accuracy: 0.8874
# Epoch 61/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.6203 - accuracy: 0.8580 - val_loss: 0.5519 - val_accuracy: 0.8888
# Epoch 62/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.6161 - accuracy: 0.8609 - val_loss: 0.5661 - val_accuracy: 0.8812
# Epoch 63/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.6112 - accuracy: 0.8617 - val_loss: 0.5559 - val_accuracy: 0.8832
# Epoch 64/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6126 - accuracy: 0.8618 - val_loss: 0.5650 - val_accuracy: 0.8821
# Epoch 65/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5969 - accuracy: 0.8650 - val_loss: 0.5672 - val_accuracy: 0.8827
# Epoch 66/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.6077 - accuracy: 0.8643 - val_loss: 0.5235 - val_accuracy: 0.8924
# Epoch 67/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.5940 - accuracy: 0.8657 - val_loss: 0.5260 - val_accuracy: 0.8932
# Epoch 68/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5884 - accuracy: 0.8677 - val_loss: 0.5220 - val_accuracy: 0.8918
# Epoch 69/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.5983 - accuracy: 0.8634 - val_loss: 0.5291 - val_accuracy: 0.8919
# Epoch 70/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.6057 - accuracy: 0.8604 - val_loss: 0.5120 - val_accuracy: 0.8949
# Epoch 71/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5804 - accuracy: 0.8687 - val_loss: 0.5830 - val_accuracy: 0.8780
# Epoch 72/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5879 - accuracy: 0.8663 - val_loss: 0.5349 - val_accuracy: 0.8891
# Epoch 73/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.5934 - accuracy: 0.8649 - val_loss: 0.5273 - val_accuracy: 0.8921
# Epoch 74/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.5860 - accuracy: 0.8672 - val_loss: 0.5702 - val_accuracy: 0.8766
# Epoch 75/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.5885 - accuracy: 0.8654 - val_loss: 0.5443 - val_accuracy: 0.8851
# Epoch 76/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5797 - accuracy: 0.8677 - val_loss: 0.5224 - val_accuracy: 0.8917
# Epoch 77/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5560 - accuracy: 0.8786 - val_loss: 0.4906 - val_accuracy: 0.9022
# Epoch 78/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.5337 - accuracy: 0.8822 - val_loss: 0.5241 - val_accuracy: 0.8913
# Epoch 79/125
# 781/781 [==============================] - 54s 70ms/step - loss: 0.5340 - accuracy: 0.8827 - val_loss: 0.4678 - val_accuracy: 0.9078
# Epoch 80/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5283 - accuracy: 0.8812 - val_loss: 0.5054 - val_accuracy: 0.8964
# Epoch 81/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5220 - accuracy: 0.8814 - val_loss: 0.5175 - val_accuracy: 0.8936
# Epoch 82/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5105 - accuracy: 0.8852 - val_loss: 0.4640 - val_accuracy: 0.9079
# Epoch 83/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5215 - accuracy: 0.8809 - val_loss: 0.4414 - val_accuracy: 0.9147
# Epoch 84/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5145 - accuracy: 0.8850 - val_loss: 0.4568 - val_accuracy: 0.9103
# Epoch 85/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5060 - accuracy: 0.8882 - val_loss: 0.4533 - val_accuracy: 0.9097
# Epoch 86/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5132 - accuracy: 0.8852 - val_loss: 0.4387 - val_accuracy: 0.9114
# Epoch 87/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5058 - accuracy: 0.8862 - val_loss: 0.4514 - val_accuracy: 0.9098
# Epoch 88/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.5108 - accuracy: 0.8840 - val_loss: 0.4553 - val_accuracy: 0.9080
# Epoch 89/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4963 - accuracy: 0.8881 - val_loss: 0.5243 - val_accuracy: 0.8917
# Epoch 90/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4958 - accuracy: 0.8878 - val_loss: 0.4609 - val_accuracy: 0.9048
# Epoch 91/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4974 - accuracy: 0.8871 - val_loss: 0.4528 - val_accuracy: 0.9086
# Epoch 92/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4898 - accuracy: 0.8893 - val_loss: 0.4449 - val_accuracy: 0.9096
# Epoch 93/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4874 - accuracy: 0.8889 - val_loss: 0.4686 - val_accuracy: 0.9042
# Epoch 94/125
# 781/781 [==============================] - 55s 70ms/step - loss: 0.4915 - accuracy: 0.8878 - val_loss: 0.4149 - val_accuracy: 0.9172
# Epoch 95/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4886 - accuracy: 0.8866 - val_loss: 0.4444 - val_accuracy: 0.9111
# Epoch 96/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4866 - accuracy: 0.8883 - val_loss: 0.4413 - val_accuracy: 0.9079
# Epoch 97/125
# 781/781 [==============================] - 55s 70ms/step - loss: 0.4922 - accuracy: 0.8873 - val_loss: 0.4626 - val_accuracy: 0.9049
# Epoch 98/125
# 781/781 [==============================] - 54s 70ms/step - loss: 0.4902 - accuracy: 0.8862 - val_loss: 0.4414 - val_accuracy: 0.9103
# Epoch 99/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4792 - accuracy: 0.8938 - val_loss: 0.4655 - val_accuracy: 0.9034
# Epoch 100/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4809 - accuracy: 0.8893 - val_loss: 0.4951 - val_accuracy: 0.8957
# Epoch 101/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4874 - accuracy: 0.8866 - val_loss: 0.4365 - val_accuracy: 0.9114
# Epoch 102/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4760 - accuracy: 0.8916 - val_loss: 0.4388 - val_accuracy: 0.9104
# Epoch 103/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4769 - accuracy: 0.8911 - val_loss: 0.4610 - val_accuracy: 0.9041
# Epoch 104/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4792 - accuracy: 0.8905 - val_loss: 0.4490 - val_accuracy: 0.9039
# Epoch 105/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4803 - accuracy: 0.8911 - val_loss: 0.4123 - val_accuracy: 0.9180
# Epoch 106/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4793 - accuracy: 0.8890 - val_loss: 0.4651 - val_accuracy: 0.9000
# Epoch 107/125
# 781/781 [==============================] - 55s 70ms/step - loss: 0.4806 - accuracy: 0.8888 - val_loss: 0.4411 - val_accuracy: 0.9082
# Epoch 108/125
# 781/781 [==============================] - 54s 70ms/step - loss: 0.4823 - accuracy: 0.8872 - val_loss: 0.4429 - val_accuracy: 0.9086
# Epoch 109/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4692 - accuracy: 0.8899 - val_loss: 0.4040 - val_accuracy: 0.9188
# Epoch 110/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4664 - accuracy: 0.8948 - val_loss: 0.4345 - val_accuracy: 0.9086
# Epoch 111/125
# 781/781 [==============================] - 54s 69ms/step - loss: 0.4709 - accuracy: 0.8914 - val_loss: 0.4709 - val_accuracy: 0.8999
# Epoch 112/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4662 - accuracy: 0.8931 - val_loss: 0.4245 - val_accuracy: 0.9137
# Epoch 113/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4663 - accuracy: 0.8920 - val_loss: 0.5158 - val_accuracy: 0.8884
# Epoch 114/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4661 - accuracy: 0.8940 - val_loss: 0.4510 - val_accuracy: 0.9047
# Epoch 115/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4685 - accuracy: 0.8920 - val_loss: 0.4203 - val_accuracy: 0.9138
# Epoch 116/125
# 781/781 [==============================] - 53s 67ms/step - loss: 0.4676 - accuracy: 0.8920 - val_loss: 0.4222 - val_accuracy: 0.9107
# Epoch 117/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.4674 - accuracy: 0.8930 - val_loss: 0.4030 - val_accuracy: 0.9204
# Epoch 118/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4715 - accuracy: 0.8912 - val_loss: 0.4534 - val_accuracy: 0.9037
# Epoch 119/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4648 - accuracy: 0.8927 - val_loss: 0.4249 - val_accuracy: 0.9126
# Epoch 120/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4644 - accuracy: 0.8906 - val_loss: 0.4359 - val_accuracy: 0.9070
# Epoch 121/125
# 781/781 [==============================] - 52s 67ms/step - loss: 0.4580 - accuracy: 0.8940 - val_loss: 0.4460 - val_accuracy: 0.9057
# Epoch 122/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4651 - accuracy: 0.8919 - val_loss: 0.4862 - val_accuracy: 0.8938
# Epoch 123/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4645 - accuracy: 0.8929 - val_loss: 0.4236 - val_accuracy: 0.9115
# Epoch 124/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4663 - accuracy: 0.8929 - val_loss: 0.5416 - val_accuracy: 0.8816
# Epoch 125/125
# 781/781 [==============================] - 53s 68ms/step - loss: 0.4667 - accuracy: 0.8926 - val_loss: 0.4507 - val_accuracy: 0.9067

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                10250
# =================================================================
# Total params: 1,455,434
# Trainable params: 1,453,130
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
#testing
scores = model.evaluate(x_test, y_test, batch_size=64, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4507 - accuracy: 0.9067
#
# Test result: 90.670 loss: 0.451

# %%
f, (plt1, plt2) = plt.subplots(1, 2,figsize=(15,5))

plt1.plot(history.history['accuracy'])
plt1.plot(history.history['val_accuracy'])
plt1.set_title('Accuracy (Higher Better)')
plt1.set(xlabel='Epoch', ylabel='Accuracy')
plt1.legend(['train', 'validation'], loc='lower right')
plt1.xaxis.set_major_locator(MaxNLocator(integer=True))

plt2.plot(history.history['loss'])
plt2.plot(history.history['val_loss'])
plt2.set_title('Loss (Lower Better)')
plt2.set(xlabel='Epoch', ylabel='Loss')
plt2.legend(['train', 'validation'], loc='upper right')
plt2.xaxis.set_major_locator(MaxNLocator(integer=True))

# %%
saved_model_dir = 'saved_model'
tf.saved_model.save(model, saved_model_dir)
 
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
tflite_model = converter.convert()
 
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: saved_model/assets

# %%
output = model.predict_classes(x_test)
print (output)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [3 8 8 ... 5 1 7]

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = y_train.reshape(y_train.shape[0])
y_test = y_test.reshape(y_test.shape[0])
ind = np.where(np.equal(output, y_test)==0)

# %%
err_x = x_test[ind[0]]
err_y = output[ind[0]]
print (err_x.shape)
# Out:
# (933, 32, 32, 3)

# %%
examples_per_class = 6
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(18,18))
for cls, cls_name in enumerate(class_names):
  idxs = np.where(cls == err_y)
  idxs = np.random.choice(idxs[0], examples_per_class, replace=False)
  for i, idx in enumerate(idxs):
    plt.subplot(examples_per_class, len(class_names), i * len(class_names) + cls + 1)
    plt.imshow(err_x[idx].astype('uint8'), cmap = 'gray')
    plt.axis('off')
    if i == 0:
      plt.title(cls_name)
plt.show()
